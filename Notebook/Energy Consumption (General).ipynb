# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # This notebook is for the Energy Consumption (Sub-Topic: General Energy)

# %%
se4all_df = pd.read_excel('../Data/SE4ALLEXCEL.xlsx')
se4all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2849 entries, 0 to 2848
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    2849 non-null   object
#  1   Country Code    2849 non-null   object
#  2   Indicator Name  2849 non-null   object
#  3   Indicator Code  2849 non-null   object
#  4   1990            2120 non-null   float64
#  5   1991            2121 non-null   float64
#  6   1992            2139 non-null   float64
#  7   1993            2137 non-null   float64
#  8   1994            2145 non-null   float64
#  9   1995            2160 non-null   float64
#  10  1996            2165 non-null   float64
#  11  1997            2168 non-null   float64
#  12  1998            2169 non-null   float64
#  13  1999            2173 non-null   float64
#  14  2000            2372 non-null   float64
#  15  2001            2375 non-null   float64
#  16  2002            2384 non-null   float64
# ...

# %%
solarpv_df = pd.read_excel('../Data/solargis_pvpotential_countryranking_2020_data.xlsx',sheet_name='Country indicators',skiprows=1)
solarpv_df.head()
# Out:
#   ISO_A3 Country or region Note World Bank \nRegion  Total population, 2018  \
# 0    ABW     Aruba (Neth.)  NaN               Other                  105845
# 1    AFG       Afghanistan  NaN                 SOA                37172386
# 2    AGO            Angola  NaN                 AFR                30809762
# 3    ALB           Albania  NaN                 ECA                 2866376
# 4    AND           Andorra  NaN               Other                   77006
#
#    Total area, 2018  Evaluated area  Level 1 area \n(% of evaluated area)  \
# 0             180.0             180                              0.847926
# 1          652860.0          652860                              0.587350
# 2         1246700.0         1246700                              0.751833
# 3           27400.0           27400                              0.614858
# 4             470.0             470                              0.110961
#
#    Human development \nIndex, 2017  \
# ...

# %% [markdown]
# # Find the total final energy consumption and renewable energy consumption

# %%
tot_energy_consum_se4all = se4all_df[se4all_df['Indicator Name']=='Total final energy consumption (TFEC) (TJ)']
tot_energy_consum_se4all
# Out:
#                     Country Name Country Code  \
# 10                   BES Islands          BES
# 21                         Nauru          NRU
# 32                          Niue          NIU
# 43             Wallis and Futuna          WLF
# 54    Caucasian and Central Asia          CCA
# ...                          ...          ...
# 2804          West Bank and Gaza          PSE
# 2815              Western Sahara          ESH
# 2826                 Yemen, Rep.          YEM
# 2837                      Zambia          ZMB
# 2848                    Zimbabwe          ZWE
#
#                                   Indicator Name  \
# 10    Total final energy consumption (TFEC) (TJ)
# 21    Total final energy consumption (TFEC) (TJ)
# 32    Total final energy consumption (TFEC) (TJ)
# 43    Total final energy consumption (TFEC) (TJ)
# 54    Total final energy consumption (TFEC) (TJ)
# ...                                          ...
# 2804  Total final energy consumption (TFEC) (TJ)
# ...

# %%
renew_energy_consum_se4all = se4all_df[se4all_df['Indicator Name']=='Renewable energy consumption (TJ)']
renew_energy_consum_se4all
# Out:
#                     Country Name Country Code  \
# 7                    BES Islands          BES
# 18                         Nauru          NRU
# 29                          Niue          NIU
# 40             Wallis and Futuna          WLF
# 51    Caucasian and Central Asia          CCA
# ...                          ...          ...
# 2801          West Bank and Gaza          PSE
# 2812              Western Sahara          ESH
# 2823                 Yemen, Rep.          YEM
# 2834                      Zambia          ZMB
# 2845                    Zimbabwe          ZWE
#
#                          Indicator Name      Indicator Code          1990  \
# 7     Renewable energy consumption (TJ)  3.1_RE.CONSUMPTION           NaN
# 18    Renewable energy consumption (TJ)  3.1_RE.CONSUMPTION       0.00000
# 29    Renewable energy consumption (TJ)  3.1_RE.CONSUMPTION       0.33076
# 40    Renewable energy consumption (TJ)  3.1_RE.CONSUMPTION       0.00000
# ...

# %% [markdown]
# # Find the electric power consumption

# %% [markdown]
# What to do in the situation of a sub-column name? A: Drop the first row

# %%
solarpv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 21 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   ISO_A3                                                                 209 non-null    object
#  1   Country or region                                                      209 non-null    object
#  2   Note                                                                   7 non-null      object
#  3   World Bank
# Region                                                     209 non-null    object
#  4   Total population, 2018                                                 209 non-null    int64
#  5   Total area, 2018                                                       207 non-null    float64
# ...

# %%
electric_consum_solarpv = solarpv_df[['Electric power consumption (kWh per capita), 2014','Country or region','Total population, 2018']]
electric_consum_solarpv
# Out:
#      Electric power consumption (kWh per capita), 2014  Country or region  \
# 0                                                  NaN      Aruba (Neth.)
# 1                                                  NaN        Afghanistan
# 2                                           312.228825             Angola
# 3                                          2309.366503            Albania
# 4                                                  NaN            Andorra
# ..                                                 ...                ...
# 204                                                NaN             Kosovo
# 205                                         219.799922  Republic of Yemen
# 206                                        4197.907047       South Africa
# 207                                         717.349168             Zambia
# 208                                         609.125952           Zimbabwe
#
#      Total population, 2018
# 0                    105845
# ...
